# %%
# this notebook is intended to be run inside a job to pass values to the next notebook(incremental)
srcArray = [
    {"filename": "customers"},
    {"filename": "transactions"},
    {"filename": "products"}
]

# %%
dbutils.jobs.taskValues.set(key = "outputkey", value = srcArray)
